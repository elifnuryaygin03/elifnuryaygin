# %% [markdown]
# <a href="https://colab.research.google.com/github/elifnuryaygin03/elifnuryaygin/blob/main/connect_session_04_problems.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Problem Statements

# %% [markdown]
# # Question 1: Electricity Bill Calculator
#
# You are tasked with developing a program that calculates the electricity bill for a user based on their energy consumption in kilowatt-hours (kWh). The program follows a tiered pricing structure:
#
# ## Pricing Tiers
# 1. If the energy consumption is between 0 and 400 kWh (both inclusive), the cost is calculated as the consumption multiplied by USD 0.20 per kWh.
#
# 2. If the energy consumption is between 400 and 800 kWh (both inclusive), a base cost of USD 80 is added, and the additional consumption beyond 400 kWh is charged at USD 0.15 per kWh.
#
# 3. If the energy consumption is between 800 and 1200 kWh (both inclusive), a base cost of USD 140 is added, and the additional consumption beyond 800 kWh is charged at USD 0.12 per kWh.
#
# 4. If the energy consumption exceeds 1200 kWh, the cost is calculated as the square root of the consumption plus 10% of the total consumption.
#
# ## Program Implementation
#
# Your task is to implement the `electricity_bill` function, which takes the energy consumption as input and returns the calculated cost. Additionally, the program includes a loop that repeatedly prompts the user for their monthly energy consumption, calculates the corresponding electricity bill, and allows the user to end the loop by entering 'Y' or 'YES' when prompted.
#
# Ensure that the program provides a clear and user-friendly interface, displaying the calculated cost with two decimal places.

# %% [markdown]
# ### Sample Output

# %% [markdown]
# ![Screenshot 2023-11-11 at 5.01.15 PM.png](data:image/png;base64,...)

# %% [markdown]
# # Question 2: Dog and Tibetan Mastiff Classes
#
# ## Dog Class
# Implement a Python class named `Dog` that represents information about dogs. The class should have the following attributes:
# - `breed` (string): representing the breed of the dog.
# - `size` (string): representing the size of the dog.
# - `age` (string): representing the age of the dog.
# - `colour` (string): representing the colour of the dog.
#
# Additionally, the `Dog` class should have the following methods:
# - `eat`: prints a message indicating that the dog is eating.
# - `sleep`: prints a message indicating that the dog is sleeping.
# - `sit`: prints a message indicating that the dog is sitting.
# - `run`: prints a message indicating that the dog is running.
#
# ## TibetanMastiff Class
# Implement a Python class named `TibetanMastiff` that inherits from the `Dog` class. The `TibetanMastiff` class should have a constructor that calls the constructor of the parent class (`Dog`). Create an instance of the `TibetanMastiff` class and demonstrate its usage by calling the inherited methods.
#
# ## Dog Instances
# Create instances of the `Dog` class for different dog breeds, such as Neapolitan Mastiff, Maltese, and Chow-Chow. Demonstrate the usage of the methods for each instance.
#
# Ensure that your code is well-documented, and there are appropriate comments for clarity.

# %% [markdown]
# # Question 3: Sentence Processing Functions
#
# Implement a Python code snippet that defines two functions for sentence processing.
#
# ## Lower Case Function
# Implement a Python function named `lower_case` that takes a sentence as input and returns the sentence in lowercase.
#
# ## Replace Vowels Function
# Implement another Python function named `replace_vowels` that takes a sentence as input and returns a new sentence with all lowercase vowels replaced by their uppercase counterparts.
#
# ## Main Program
# Write a main program that:
# 1. Takes a sentence as input from the user.
# 2. Calls the `lower_case` function to convert the sentence to lowercase.
# 3. Calls the `replace_vowels` function with the lowercase sentence and prints the result.
#
# Ensure that your code is well-documented, and there are appropriate comments for clarity. Demonstrate the usage of both functions with meaningful examples.

# %% [markdown]
# ### Sample Output
# ![Screenshot 2023-11-11 at 5.31.37 PM.png](data:image/png;base64,...)

# %% [markdown]
# # Question 4: Guessing Game Class
#
# Implement a Python code snippet that defines a `GuessingGame` class for a simple number guessing game.
#
# ## GuessingGame Class
# Create a Python class named `GuessingGame` that represents a number guessing game. The class should have the following features:
#
# ### Constructor
# - A constructor to initialize the following instance attributes:
#   - `num_guesses` (integer, default 10): representing the maximum number of guesses allowed.
#   - `range_values` (tuple of two integers, default (1, 99)): representing the range of values within which the computer generates a random number.
#
# ### Methods
# 1. `_play`: a private method that simulates a single round of the game. The computer generates a random number within the specified range, and the user has a limited number of guesses to figure out the correct number. The method returns a boolean indicating whether the user won or lost.
#
# 2. `trials`: a method that simulates multiple trials of the game. It takes an optional parameter `num_games` (integer, default 3) representing the number of games to be played. The method prints the outcome of each game (win or loss) and then determines if the user won the majority of the games.
#
# ### Main Program
# Write a main program that:
# - Creates an instance of the `GuessingGame` class.
# - Calls the `trials` method to simulate multiple games and prints the overall outcome.
#
# Ensure that your code is well-documented, and there are appropriate comments for clarity. Demonstrate the usage of the `GuessingGame` class with meaningful examples.

# %% [markdown]
# ### Sample output
# ![Screenshot 2023-11-11 at 5.15.21 PM.png](data:image/png;base64,...)
